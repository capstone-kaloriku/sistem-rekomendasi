# %%
# %pip install tensorflowjs
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflowjs as tfjs
import tensorflow as tf
models = [
    "best_rating_prediction_model.keras",
    "nlp_recommendation_model.keras"
]
for model_path in models:
    # Load model
    model = tf.keras.models.load_model(model_path)
    # Convert and save
    output_dir = model_path.replace(".keras", "_tfjs")
    tfjs.converters.save_keras_model(model, output_dir)
    print(f"Converted TFJS model to directory: {output_dir}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflowjs as tfjs
#       2 import tensorflow as tf
#       3 models = [
#       4     "best_rating_prediction_model.keras",
#       5     "nlp_recommendation_model.keras"
#       6 ]
#
# ModuleNotFoundError: No module named 'tensorflowjs'
